# %% [markdown]
# <a href="https://colab.research.google.com/github/GautamPoddar18/Melanoma-Detection-Assignment/blob/main/starter_notebook_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem statement:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ### Importing Data

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("../input/melanoma-detection-dataset/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('../input/melanoma-detection-dataset/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.
# 2022-11-21 08:51:28.672910: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:28.796189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:28.797017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:28.800774: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-21 08:51:28.801071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:28.801836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:28.802490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:31.300824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:31.301636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:31.302298: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 08:51:31.302872: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Below is the code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.image as mpimg
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = mpimg.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Below is the first base model`we have created:

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
from tensorflow.keras.optimizers import RMSprop

# %% [markdown]
# ### As it is a multi class classification, we are using SparseCategoricalCrossEntropy as the loss function, and we are using adam optimizer as a hit & trial, further we can perform hyper parameter optimization and change the optimizer accordingly

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 32)      2432
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 180, 180, 32)      25632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 90, 90, 32)        25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 45, 45, 32)        25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 22, 22, 32)        25632
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 11, 11, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3872)              0
# _________________________________________________________________
# dense (Dense)                (None, 9)                 34857
# =================================================================
# Total params: 139,817
# Trainable params: 139,817
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.7/site-packages/keras/backend.py:4907: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 2022-11-21 08:51:34.457078: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-11-21 08:51:44.611094: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 26 of 1000
# 2022-11-21 08:51:50.924066: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 2022-11-21 08:51:51.668858: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 56/56 [==============================] - 31s 127ms/step - loss: 2.0529 - accuracy: 0.1836 - val_loss: 2.0252 - val_accuracy: 0.2349
# Epoch 2/30
# 56/56 [==============================] - 2s 43ms/step - loss: 1.9957 - accuracy: 0.2383 - val_loss: 1.9286 - val_accuracy: 0.3087
# Epoch 3/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.8360 - accuracy: 0.3304 - val_loss: 1.7956 - val_accuracy: 0.3356
# Epoch 4/30
# 56/56 [==============================] - 2s 41ms/step - loss: 1.6761 - accuracy: 0.3929 - val_loss: 1.5412 - val_accuracy: 0.4385
# Epoch 5/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.5894 - accuracy: 0.4230 - val_loss: 1.7343 - val_accuracy: 0.3691
# Epoch 6/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.5624 - accuracy: 0.4386 - val_loss: 1.5214 - val_accuracy: 0.4497
# Epoch 7/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.4737 - accuracy: 0.4665 - val_loss: 1.4799 - val_accuracy: 0.4720
# Epoch 8/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.4436 - accuracy: 0.4799 - val_loss: 1.6888 - val_accuracy: 0.3870
# Epoch 9/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.3804 - accuracy: 0.5056 - val_loss: 1.5522 - val_accuracy: 0.4720
# Epoch 10/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.3219 - accuracy: 0.5480 - val_loss: 1.3668 - val_accuracy: 0.5123
# Epoch 11/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.2283 - accuracy: 0.5647 - val_loss: 1.3772 - val_accuracy: 0.5123
# Epoch 12/30
# 56/56 [==============================] - 2s 41ms/step - loss: 1.1916 - accuracy: 0.5709 - val_loss: 1.5114 - val_accuracy: 0.4541
# Epoch 13/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.1453 - accuracy: 0.6010 - val_loss: 1.4768 - val_accuracy: 0.5011
# Epoch 14/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.1032 - accuracy: 0.6138 - val_loss: 1.3986 - val_accuracy: 0.5347
# Epoch 15/30
# 56/56 [==============================] - 2s 42ms/step - loss: 1.0454 - accuracy: 0.6317 - val_loss: 1.4393 - val_accuracy: 0.5145
# Epoch 16/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.9642 - accuracy: 0.6613 - val_loss: 1.4930 - val_accuracy: 0.5011
# Epoch 17/30
# 56/56 [==============================] - 2s 42ms/step - loss: 0.9134 - accuracy: 0.6724 - val_loss: 1.5765 - val_accuracy: 0.5034
# Epoch 18/30
# 56/56 [==============================] - 2s 42ms/step - loss: 0.8995 - accuracy: 0.6802 - val_loss: 1.5595 - val_accuracy: 0.5123
# Epoch 19/30
# 56/56 [==============================] - 2s 42ms/step - loss: 0.8029 - accuracy: 0.7160 - val_loss: 1.5145 - val_accuracy: 0.5145
# Epoch 20/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.8079 - accuracy: 0.7126 - val_loss: 1.6499 - val_accuracy: 0.5056
# Epoch 21/30
# 56/56 [==============================] - 2s 42ms/step - loss: 0.6995 - accuracy: 0.7500 - val_loss: 1.7706 - val_accuracy: 0.5123
# Epoch 22/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6487 - accuracy: 0.7662 - val_loss: 2.0097 - val_accuracy: 0.5324
# Epoch 23/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6221 - accuracy: 0.7634 - val_loss: 1.8515 - val_accuracy: 0.4922
# Epoch 24/30
# 56/56 [==============================] - 2s 42ms/step - loss: 0.6164 - accuracy: 0.7757 - val_loss: 1.9789 - val_accuracy: 0.4765
# Epoch 25/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6074 - accuracy: 0.7718 - val_loss: 2.0529 - val_accuracy: 0.5101
# Epoch 26/30
# 56/56 [==============================] - 2s 41ms/step - loss: 0.5171 - accuracy: 0.8013 - val_loss: 2.0311 - val_accuracy: 0.4586
# Epoch 27/30
# 56/56 [==============================] - 2s 43ms/step - loss: 0.5179 - accuracy: 0.8064 - val_loss: 2.1297 - val_accuracy: 0.4966
# Epoch 28/30
# 56/56 [==============================] - 2s 42ms/step - loss: 0.4604 - accuracy: 0.8292 - val_loss: 2.3562 - val_accuracy: 0.5101
# Epoch 29/30
# 56/56 [==============================] - 2s 42ms/step - loss: 0.4802 - accuracy: 0.8175 - val_loss: 2.2464 - val_accuracy: 0.5145
# Epoch 30/30
# 56/56 [==============================] - 2s 42ms/step - loss: 0.4458 - accuracy: 0.8292 - val_loss: 2.4221 - val_accuracy: 0.4743

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Findings on the first base model
#
#
# *   Initial findings: The model is overfitting because overfitting is calculated w.r.t loss, and we can also see difference in loss functions in training & test around the 19-20th epoch
# *   The accuracy is just around 50-60% because there are enough features to remember the pattern, and the neural network is very young (just 20 epochs), so the learning has just started
# *   But again, it's too early to comment on the overfitting & underfitting debate

# %%
data_aug = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_aug(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Model Creation, compilation and training the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_aug,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 100 epochs
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 3s 48ms/step - loss: 2.0624 - accuracy: 0.1881 - val_loss: 2.0332 - val_accuracy: 0.2058
# Epoch 2/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.9951 - accuracy: 0.2199 - val_loss: 2.0323 - val_accuracy: 0.2148
# Epoch 3/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.9192 - accuracy: 0.2896 - val_loss: 1.8612 - val_accuracy: 0.2595
# Epoch 4/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.7902 - accuracy: 0.3242 - val_loss: 1.6869 - val_accuracy: 0.3691
# Epoch 5/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.6856 - accuracy: 0.3772 - val_loss: 1.7083 - val_accuracy: 0.4094
# Epoch 6/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.6316 - accuracy: 0.4068 - val_loss: 1.6271 - val_accuracy: 0.4430
# Epoch 7/30
# 56/56 [==============================] - 3s 46ms/step - loss: 1.5997 - accuracy: 0.4169 - val_loss: 1.5282 - val_accuracy: 0.4810
# Epoch 8/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.5558 - accuracy: 0.4392 - val_loss: 1.4900 - val_accuracy: 0.4877
# Epoch 9/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4972 - accuracy: 0.4693 - val_loss: 1.5625 - val_accuracy: 0.4676
# Epoch 10/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4893 - accuracy: 0.4799 - val_loss: 1.5852 - val_accuracy: 0.4430
# Epoch 11/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.5261 - accuracy: 0.4688 - val_loss: 1.6142 - val_accuracy: 0.4653
# Epoch 12/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4960 - accuracy: 0.4676 - val_loss: 1.5859 - val_accuracy: 0.4407
# Epoch 13/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4384 - accuracy: 0.4838 - val_loss: 1.4678 - val_accuracy: 0.4989
# Epoch 14/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4796 - accuracy: 0.4682 - val_loss: 1.4426 - val_accuracy: 0.4989
# Epoch 15/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4096 - accuracy: 0.4994 - val_loss: 1.4271 - val_accuracy: 0.5347
# Epoch 16/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4202 - accuracy: 0.4983 - val_loss: 1.4490 - val_accuracy: 0.5034
# Epoch 17/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3619 - accuracy: 0.5151 - val_loss: 1.4385 - val_accuracy: 0.5101
# Epoch 18/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3514 - accuracy: 0.5167 - val_loss: 1.3910 - val_accuracy: 0.5391
# Epoch 19/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.3707 - accuracy: 0.5134 - val_loss: 1.3738 - val_accuracy: 0.5123
# Epoch 20/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3204 - accuracy: 0.5324 - val_loss: 1.4627 - val_accuracy: 0.4855
# Epoch 21/30
# 56/56 [==============================] - 2s 45ms/step - loss: 1.3633 - accuracy: 0.5100 - val_loss: 1.4320 - val_accuracy: 0.5213
# Epoch 22/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3254 - accuracy: 0.5212 - val_loss: 1.4730 - val_accuracy: 0.4653
# Epoch 23/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3079 - accuracy: 0.5290 - val_loss: 1.3895 - val_accuracy: 0.4966
# Epoch 24/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2866 - accuracy: 0.5324 - val_loss: 1.4329 - val_accuracy: 0.5123
# Epoch 25/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3208 - accuracy: 0.5167 - val_loss: 1.4089 - val_accuracy: 0.5235
# Epoch 26/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2921 - accuracy: 0.5430 - val_loss: 1.3823 - val_accuracy: 0.5168
# Epoch 27/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2757 - accuracy: 0.5463 - val_loss: 1.4226 - val_accuracy: 0.5257
# Epoch 28/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2611 - accuracy: 0.5430 - val_loss: 1.3741 - val_accuracy: 0.5056
# Epoch 29/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.2656 - accuracy: 0.5352 - val_loss: 1.3466 - val_accuracy: 0.5324
# Epoch 30/30
# 56/56 [==============================] - 2s 45ms/step - loss: 1.2516 - accuracy: 0.5508 - val_loss: 1.3528 - val_accuracy: 0.5235

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Findings:
#
#
# *   We don't see much improvements with respect to accuracy from the base model, but we can definitely see the overfitting issue fading away due to data augmentation
# *   But again, judging based on just 20 epochs won't give us proper conclusions

# %% [markdown]
# ## Finding the distribution of classes in the training dataset.

# %%
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# 1     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# 2     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# 3     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# 4     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# ...                                                 ...                ...
# 2234  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
# 2235  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
# 2236  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
# 2237  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
# 2238  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# 1     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# 2     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# 3     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# 4     ../input/melanoma-detection-dataset/Skin cance...  actinic keratosis
# ...                                                 ...                ...
# 2234  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
# 2235  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
# 2236  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
# 2237  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
# 2238  ../input/melanoma-detection-dataset/Skin cance...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ### Findings
#
# #### - Seborrheic keratosis is having the lowest distribution
# #### - Pigmented Benign keratosis is having the highest distribution of data

# %% [markdown]
# #### Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
